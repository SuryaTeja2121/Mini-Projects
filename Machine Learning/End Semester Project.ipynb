# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Reading the Dataset

# %%
df=pd.read_csv("twitchdata-update.csv")
df.head()
# Out:
#     Channel  Watch time(Minutes)  Stream time(minutes)  Peak viewers  \
# 0     xQcOW           6196161750                215250        222720
# 1  summit1g           6091677300                211845        310998
# 2    Gaules           5644590915                515280        387315
# 3  ESL_CSGO           3970318140                517740        300575
# 4      Tfue           3671000070                123660        285644
#
#    Average viewers  Followers  Followers gained  Views gained  Partnered  \
# 0            27716    3246298           1734810      93036735       True
# 1            25610    5310163           1370184      89705964       True
# 2            10976    1767635           1023779     102611607       True
# 3             7714    3944850            703986     106546942       True
# 4            29602    8938903           2068424      78998587       True
#
#    Mature    Language
# 0   False     English
# 1   False     English
# 2    True  Portuguese
# 3   False     English
# 4   False     English

# %% [markdown]
# # Data Preprocessing

# %%
df.isnull().sum()
# Out:
# Channel                 0
# Watch time(Minutes)     0
# Stream time(minutes)    0
# Peak viewers            0
# Average viewers         0
# Followers               0
# Followers gained        0
# Views gained            0
# Partnered               0
# Mature                  0
# Language                0
# dtype: int64

# %%
df.dtypes
# Out:
# Channel                 object
# Watch time(Minutes)      int64
# Stream time(minutes)     int64
# Peak viewers             int64
# Average viewers          int64
# Followers                int64
# Followers gained         int64
# Views gained             int64
# Partnered                 bool
# Mature                    bool
# Language                object
# dtype: object

# %%
df.describe()
# Out:
#        Watch time(Minutes)  Stream time(minutes)   Peak viewers  \
# count         1.000000e+03           1000.000000    1000.000000
# mean          4.184279e+08         120515.160000   37065.051000
# std           5.496355e+08          85376.201364   60314.307686
# min           1.221928e+08           3465.000000     496.000000
# 25%           1.631899e+08          73758.750000    9113.750000
# 50%           2.349908e+08         108240.000000   16676.000000
# 75%           4.337399e+08         141843.750000   37569.750000
# max           6.196162e+09         521445.000000  639375.000000
#
#        Average viewers     Followers  Followers gained  Views gained
# count      1000.000000  1.000000e+03      1.000000e+03  1.000000e+03
# mean       4781.040000  5.700541e+05      2.055185e+05  1.166817e+07
# std        8453.684965  8.044134e+05      3.399137e+05  2.490572e+07
# min         235.000000  3.660000e+03     -1.577200e+04  1.757880e+05
# 25%        1457.750000  1.705462e+05      4.375825e+04  3.880602e+06
# 50%        2425.000000  3.180630e+05      9.835200e+04  6.456324e+06
# 75%        4786.250000  6.243322e+05      2.361308e+05  1.219676e+07
# max      147643.000000  8.938903e+06      3.966525e+06  6.701375e+08

# %% [markdown]
# # Data Visualisation

# %%
plt.figure(figsize = (25,10))
df['Stream time(minutes)'].head(75).plot.bar(color = 'blue')
plt.title('Comparing the different stream times (in minutes)')
plt.xlabel('Streamer')
plt.ylabel('Stream time')
plt.show()

# %%
plt.figure(figsize = (25,10))
df['Followers gained'].head(75).plot.bar(color = 'blue')
plt.title('Comparing the followers gained by our Top 50 Streamers')
plt.xlabel('Streamer')
plt.ylabel('Followers Gained')
plt.show()

# %%
plt.figure(figsize = (25,10))
df['Views gained'].head(75).plot.bar(color = 'blue')
plt.title('Comparing the views gained by our Top 50 Streamers')
plt.xlabel('Streamer')
plt.ylabel('Views Gained')
plt.show()

# %%
plt.figure(figsize = (25,10))
df['Average viewers'].head(75).plot.bar(color = 'blue')
plt.title('Comparing the average viewers of our Top 50 Streamers')
plt.xlabel('Streamer')
plt.ylabel('Average Viewers ')
plt.show()

# %%
plt.figure(figsize = (25,10))
df['Language'].value_counts().head(75).plot.bar(color = 'blue')
plt.title('Languages that Streamers stream in')
plt.xlabel('Languages')
plt.ylabel('Number of Streamers')
plt.show()

# %%
sns.set_theme(style="darkgrid")
sns.countplot(x='Partnered',data = df,palette="Set1")
# Out:
# <AxesSubplot:xlabel='Partnered', ylabel='count'>

# %%
sns.countplot(x='Mature',data = df,palette="Set1")
# Out:
# <AxesSubplot:xlabel='Mature', ylabel='count'>

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df[['Channel', 'Watch time(Minutes)', 'Stream time(minutes)', 'Followers','Peak viewers','Average viewers','Followers gained','Views gained','Partnered','Mature','Language']].corr(), annot = True,cmap="YlGnBu") #overall correlation between the various columns present in our data
plt.title('Overall relation between columns of the Dataset', fontsize = 20)
plt.show()

# %% [markdown]
# <div class="alert-success">
#  Accessing DataSet
# </div>

# %%
def streamer(x): 
    return df.loc[df['Channel']==x]

# %%
streamer('aceu')
# Out:
#     Channel  Watch time(Minutes)  Stream time(minutes)  Peak viewers  \
# 119    aceu            744620970                118125         26141
#
#      Average viewers  Followers  Followers gained  Views gained  Partnered  \
# 119             6328     859439            763489      15894732       True
#
#      Mature Language
# 119    True  English

# %%
def streamtime(x): 
    return df.loc[df['Stream time(minutes)']==x]
def watchtime(x): 
    return df.loc[df['Watch time(Minutes)']==x]
def avgviewers(x): 
    return df.loc[df['Average viewers']==x]
def follow(x): 
    return df.loc[df['Followers']==x] 
def followgained(x): 
    return df.loc[df['Followers gained']==x] 
def viewgained(x): 
    return df.loc[df['Views gained']==x]

# %%
streamtime(df['Stream time(minutes)'].max())
# Out:
#       Channel  Watch time(Minutes)  Stream time(minutes)  Peak viewers  \
# 392  RiffTrax            293583075                521445         24765
#
#      Average viewers  Followers  Followers gained  Views gained  Partnered  \
# 392              562      79099             17200       3313465       True
#
#      Mature Language
# 392   False  English

# %%
watchtime(df['Watch time(Minutes)'].max())
# Out:
#   Channel  Watch time(Minutes)  Stream time(minutes)  Peak viewers  \
# 0   xQcOW           6196161750                215250        222720
#
#    Average viewers  Followers  Followers gained  Views gained  Partnered  \
# 0            27716    3246298           1734810      93036735       True
#
#    Mature Language
# 0   False  English

# %%
avgviewers(df['Average viewers'].max())
# Out:
#     Channel  Watch time(Minutes)  Stream time(minutes)  Peak viewers  \
# 81  dota2ti           1017577605                  6315        483530
#
#     Average viewers  Followers  Followers gained  Views gained  Partnered  \
# 81           147643     663297            121422      16228039       True
#
#     Mature Language
# 81   False  English

# %%
follow(df['Followers'].max())
# Out:
#   Channel  Watch time(Minutes)  Stream time(minutes)  Peak viewers  \
# 4    Tfue           3671000070                123660        285644
#
#    Average viewers  Followers  Followers gained  Views gained  Partnered  \
# 4            29602    8938903           2068424      78998587       True
#
#    Mature Language
# 4   False  English

# %%
avgviewers(df['Average viewers'].max())
# Out:
#     Channel  Watch time(Minutes)  Stream time(minutes)  Peak viewers  \
# 81  dota2ti           1017577605                  6315        483530
#
#     Average viewers  Followers  Followers gained  Views gained  Partnered  \
# 81           147643     663297            121422      16228039       True
#
#     Mature Language
# 81   False  English

# %%
followgained(df['Followers gained'].max())
# Out:
#       Channel  Watch time(Minutes)  Stream time(minutes)  Peak viewers  \
# 14  auronplay           2410022550                 40575        170115
#
#     Average viewers  Followers  Followers gained  Views gained  Partnered  \
# 14            53986    3983847           3966525      41514854       True
#
#     Mature Language
# 14   False  Spanish

# %%
viewgained(df['Views gained'].max())
# Out:
#       Channel  Watch time(Minutes)  Stream time(minutes)  Peak viewers  \
# 7  Fextralife           3301867485                147885         68795
#
#    Average viewers  Followers  Followers gained  Views gained  Partnered  \
# 7            18985     508816            425468     670137548       True
#
#    Mature Language
# 7   False  English

# %% [markdown]
# ## Modelling

# %%
df1 = df.copy()

# %%
df1.head()
# Out:
#     Channel  Watch time(Minutes)  Stream time(minutes)  Peak viewers  \
# 0     xQcOW           6196161750                215250        222720
# 1  summit1g           6091677300                211845        310998
# 2    Gaules           5644590915                515280        387315
# 3  ESL_CSGO           3970318140                517740        300575
# 4      Tfue           3671000070                123660        285644
#
#    Average viewers  Followers  Followers gained  Views gained  Partnered  \
# 0            27716    3246298           1734810      93036735       True
# 1            25610    5310163           1370184      89705964       True
# 2            10976    1767635           1023779     102611607       True
# 3             7714    3944850            703986     106546942       True
# 4            29602    8938903           2068424      78998587       True
#
#    Mature    Language
# 0   False     English
# 1   False     English
# 2    True  Portuguese
# 3   False     English
# 4   False     English

# %% [markdown]
# <div class="alert-info">
# Linear Regression Algorithm
# </div>

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
X = df1[['Watch time(Minutes)','Stream time(minutes)','Peak viewers','Average viewers','Followers','Views gained']]
y = df1['Followers gained']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2,random_state = 13)

# %%
X_train
# Out:
#      Watch time(Minutes)  Stream time(minutes)  Peak viewers  Average viewers  \
# 133            661075170                 41175         43877            13154
# 233            460519830                156195         20745             2552
# 643            186562710                141675         13091             1317
# 497            235689105                364425          8210              644
# 281            398289900                150495          7955             2635
# ..                   ...                   ...           ...              ...
# 742            164759730                 58395          6577             2809
# 528            224762820                141705          8886             1603
# 74            1076179485                137400         45671             7327
# 176            567374295                 58545         43422             9583
# 338            331308960                 55125         27529             5711
#
#      Followers  Views gained
# 133     825727      28719610
# 233     267004      16917944
# 643     150944       4702541
# 497     105341       7982996
# 281    1233300      19024045
# ..         ...           ...
# 742     287063       2147906
# 528      82578       5801449
# 74     2355063      18756705
# 176    1372290      17629667
# 338     786562      10562872
#
# [800 rows x 6 columns]

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train
# Out:
# array([[ 0.42830814, -0.939936  ,  0.11089161,  0.94984246,  0.33888989,
#          0.62466806],
#        [ 0.06826431,  0.41056397, -0.26625042, -0.25399266, -0.39472589,
#          0.18631392],
#        [-0.42355293,  0.24007832, -0.39104055, -0.39422435, -0.54711526,
#         -0.26740782],
#        ...,
#        [ 1.17351767,  0.18988368,  0.14014083,  0.28819869,  2.34694221,
#          0.25461178],
#        [ 0.26009311, -0.73598726,  0.10347333,  0.54436281,  1.05653931,
#          0.21274974],
#        [-0.16369949, -0.77614297, -0.1556447 ,  0.10470524,  0.28746537,
#         -0.04973513]])

# %%
linear  = LinearRegression()
linear.fit(X_train,y_train)
pred = linear.predict(X_test)

# %%
from sklearn.metrics import r2_score, mean_squared_error
#print('r2 score: '+str(r2_score(y_test, pred)))
print('RMSE : '+str(np.sqrt(mean_squared_error(y_test, pred))))
# Out:
# RMSE : 217281.69253725334

# %%
streamer("shroud")
# Out:
#    Channel  Watch time(Minutes)  Stream time(minutes)  Peak viewers  \
# 96  shroud            888505170                 30240        471281
#
#     Average viewers  Followers  Followers gained  Views gained  Partnered  \
# 96            29612    7744066            833587      30621257       True
#
#     Mature Language
# 96   False  English

# %%
user_input = [[888505170,30240,471281,29612,7744066,30621257]]        
user_pred = linear.predict(user_input)
print("Follower Gained by the streamer are:-",user_pred)
# Out:
# Follower Gained by the streamer are:- [4.14259294e+13]

# %%
plt.style.use('seaborn-dark-palette')
plt.figure(figsize=(25,10))
sns.regplot(pred,y_test,scatter_kws={'color':'yellow','edgecolor':'red','linewidth':0.7},line_kws={'color':'magenta','alpha':0.5})
plt.xlabel('Followers Gained')
plt.ylabel('Features')
plt.title("Linear Prediction of Followers Gained by a Streamer")
plt.show()
# Out:
# e:\pycode\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
